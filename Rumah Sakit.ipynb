# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('data-daftar-rumah-sakit-yang-terakreditasi-di-dki-jakarta-tahun-2019.csv')
X = dataset.iloc[:, :-1].values
y =  dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
dataset
# Out:
#      tahun_standar                            nama_rumah_sakit kelas  \
# 0             2012                   RS Umum Daerah Cengkareng     B
# 1             2012        RS Penyakit Infeksi Prof. Dr. Sulian     A
# 2             2012                   RS Umum Daerah Pasar Rebo     B
# 3             2012                         RS Umum Setia Mitra     C
# 4             2012           RS Khusus Mata Jakarta Eye Center     B
# ..             ...                                         ...   ...
# 154           2018                    RS Ibu dan Anak Sayyidah     C
# 155           2018               RS Khusus Bedah Bina Estetika     B
# 156           2018                   RS Ibu dan Anak Ibnu Sina     C
# 157           2018  RS Jantung dan Pembuluh Darah Harapan Kita     A
# 158           2018                           RSUP Persahabatan     A
#
#       kabupaten/kota tanggal_mulai_survei tanggal_masa_berlaku  \
# 0      Jakarta Barat           21/10/2019           20/10/2022
# 1      Jakarta Utara           22/11/2016           21/11/2019
# 2      Jakarta Timur           23/11/2016           22/11/2019
# 3    Jakarta Selatan           29/11/2016           28/11/2019
# 4      Jakarta Pusat           18/01/2017           17/01/2020
# ..               ...                  ...                  ...
# 154    Jakarta Timur           27/12/2018           26/12/2021
# 155    Jakarta Pusat           27/12/2018           26/12/2021
# 156    Jakarta Barat             2/1/2019             1/1/2022
# 157    Jakarta Barat            8/10/2018            7/10/2021
# 158    Jakarta Timur           26/11/2018           25/11/2021
#
#                 status tanggal_update
# 0    Tingkat Paripurna     13/11/2019
# 1    Tingkat Paripurna       4/8/2017
# 2    Tingkat Paripurna       2/9/2017
# 3    Tingkat Paripurna     16/03/2017
# 4    Tingkat Paripurna     16/03/2017
# ..                 ...            ...
# 154      Lulus Perdana       1/4/2019
# 155      Lulus Perdana       1/2/2019
# 156      Lulus Perdana     13/01/2019
# 157      International       3/7/2019
# 158      International       5/2/2019
#
# [159 rows x 8 columns]

# %%
print(X)
# Out:
# [[2012 'RS Umum Daerah Cengkareng' 'B' ... '21/10/2019' '20/10/2022'
#   'Tingkat Paripurna']
#  [2012 'RS Penyakit Infeksi Prof. Dr. Sulian' 'A' ... '22/11/2016'
#   '21/11/2019' 'Tingkat Paripurna']
#  [2012 'RS Umum Daerah Pasar Rebo' 'B' ... '23/11/2016' '22/11/2019'
#   'Tingkat Paripurna']
#  ...
#  [2018 'RS Ibu dan Anak Ibnu Sina' 'C' ... '2/1/2019' '1/1/2022'
#   'Lulus Perdana']
#  [2018 'RS Jantung dan Pembuluh Darah Harapan Kita' 'A' ... '8/10/2018'
#   '7/10/2021' 'International']
#  [2018 'RSUP Persahabatan' 'A' ... '26/11/2018' '25/11/2021'
#   'International']]

# %%
print(y)
# Out:
# ['13/11/2019' '4/8/2017' '2/9/2017' '16/03/2017' '16/03/2017' '28/02/2017'
#  '13/03/2017' '10/12/2017' '4/8/2017' '5/1/2017' '28/08/2017' '19/05/2017'
#  '6/7/2017' '6/9/2017' '6/9/2017' '28/08/2017' '15/08/2017' '15/08/2017'
#  '28/08/2017' '10/3/2017' '11/3/2017' '3/7/2018' '29/11/2017' '1/3/2018'


# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [0])], remainder='passthrough')
X = np.array(ct.fit_transform(X))

# %%
print(X)
# Out:
# [[1.0 0.0 'RS Umum Daerah Cengkareng' ... '21/10/2019' '20/10/2022'
#   'Tingkat Paripurna']
#  [1.0 0.0 'RS Penyakit Infeksi Prof. Dr. Sulian' ... '22/11/2016'
#   '21/11/2019' 'Tingkat Paripurna']
#  [1.0 0.0 'RS Umum Daerah Pasar Rebo' ... '23/11/2016' '22/11/2019'
#   'Tingkat Paripurna']
#  ...
#  [0.0 1.0 'RS Ibu dan Anak Ibnu Sina' ... '2/1/2019' '1/1/2022'
#   'Lulus Perdana']
#  [0.0 1.0 'RS Jantung dan Pembuluh Darah Harapan Kita' ... '8/10/2018'
#   '7/10/2021' 'International']
#  [0.0 1.0 'RSUP Persahabatan' ... '26/11/2018' '25/11/2021'
#   'International']]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   tahun_standar         159 non-null    int64
#  1   nama_rumah_sakit      159 non-null    object
#  2   kelas                 159 non-null    object
#  3   kabupaten/kota        159 non-null    object
#  4   tanggal_mulai_survei  159 non-null    object
#  5   tanggal_masa_berlaku  159 non-null    object
#  6   status                159 non-null    object
#  7   tanggal_update        159 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 10.1+ KB

# %%
dataset
# Out:
#      tahun_standar                            nama_rumah_sakit kelas  \
# 0             2012                   RS Umum Daerah Cengkareng     B
# 1             2012        RS Penyakit Infeksi Prof. Dr. Sulian     A
# 2             2012                   RS Umum Daerah Pasar Rebo     B
# 3             2012                         RS Umum Setia Mitra     C
# 4             2012           RS Khusus Mata Jakarta Eye Center     B
# ..             ...                                         ...   ...
# 154           2018                    RS Ibu dan Anak Sayyidah     C
# 155           2018               RS Khusus Bedah Bina Estetika     B
# 156           2018                   RS Ibu dan Anak Ibnu Sina     C
# 157           2018  RS Jantung dan Pembuluh Darah Harapan Kita     A
# 158           2018                           RSUP Persahabatan     A
#
#       kabupaten/kota tanggal_mulai_survei tanggal_masa_berlaku  \
# 0      Jakarta Barat           21/10/2019           20/10/2022
# 1      Jakarta Utara           22/11/2016           21/11/2019
# 2      Jakarta Timur           23/11/2016           22/11/2019
# 3    Jakarta Selatan           29/11/2016           28/11/2019
# 4      Jakarta Pusat           18/01/2017           17/01/2020
# ..               ...                  ...                  ...
# 154    Jakarta Timur           27/12/2018           26/12/2021
# 155    Jakarta Pusat           27/12/2018           26/12/2021
# 156    Jakarta Barat             2/1/2019             1/1/2022
# 157    Jakarta Barat            8/10/2018            7/10/2021
# 158    Jakarta Timur           26/11/2018           25/11/2021
#
#                 status tanggal_update
# 0    Tingkat Paripurna     13/11/2019
# 1    Tingkat Paripurna       4/8/2017
# 2    Tingkat Paripurna       2/9/2017
# 3    Tingkat Paripurna     16/03/2017
# 4    Tingkat Paripurna     16/03/2017
# ..                 ...            ...
# 154      Lulus Perdana       1/4/2019
# 155      Lulus Perdana       1/2/2019
# 156      Lulus Perdana     13/01/2019
# 157      International       3/7/2019
# 158      International       5/2/2019
#
# [159 rows x 8 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
print(y)
# Out:
# [20 73 36 27 27 52 17  5 73 75 55 33 83 84 84 55 25 25 55  6  9 60 59  1
#  11 18 11 60 23 32 40 57 23 37 72 39 24 87 51 50 50 71 61 47 78 13 15 69
#  78 69 26 69 76  3 69 69 62 44 62 53  8 28 58 58 30 78 76 78  8 19 89 80
#  19 41 31 54 48 65 65 89 85 66 88 90  8  7  8  8 33 73  9 11 32  4 42 15
#  69 62 78  8 53 48 48 65 86 66  7 68 56 81 14 35 45  3  3 34 74 64 78 79
#  41 82 21 67 82 34 82 48 48 48 65 65 66 43 53 34 65 49 46 27 70 77 38 63
#  14 42 63 22 10  2 12  2  2 29  3  0 16 61 78]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
print(X_train)
# Out:
# [[1.0 0.0 'RS Umum Patria IKKT' ... '19/12/2017' '18/12/2020'
#   'Tingkat Madya']
#  [0.0 1.0 'RS Umum Yadika' ... '19/06/2019' '18/06/2022' 'Tingkat Madya']
#  [0.0 1.0 'RS Islam Jakarta Pondok Kopi' ... '12/2/2019' '11/2/2022'
#   'Tingkat Paripurna']
#  ...
#  [0.0 1.0 'Rumah Sakit Gigi Dan Mulut Angkatan' ... '2/5/2019' '1/5/2022'
#   'Tingkat Paripurna']
#  [1.0 0.0 'RS Umum Harapan Jayakarta' ... '5/4/2017' '4/4/2020'
#   'Lulus Perdana']
#  [0.0 1.0 'RS Gigi dan Mulut FKG Universitas Tr' ... '31/07/2018'
#   '30/07/2021' 'Tingkat Paripurna']]

# %%
print(X_test)
# Out:
# [[1.0 0.0 'RS Gigi Dan Mulut YARSI' 'B' 'Jakarta Pusat' '11/12/2017'
#   '10/12/2020' 'Tingkat Paripurna']
#  [0.0 1.0 'RS Jantung dan Pembuluh Darah Harapa' 'A' 'Jakarta Barat'
#   '8/10/2018' '7/10/2021' 'Tingkat Paripurna']
#  [1.0 0.0 'RS Umum Hermina Daan Mogot' 'B' 'Jakarta Barat' '17/05/2017'
#   '16/05/2020' 'Tingkat Paripurna']
#  [1.0 0.0 'RS Umum Tebet' 'B' 'Jakarta Selatan' '23/11/2017' '22/11/2020'
#   'Tingkat Utama']
#  [0.0 1.0 'RS Tk IV Cijantung' 'C' 'Jakarta Timur' '13/08/2019'
#   '12/8/2022' 'Tingkat Paripurna']
#  [1.0 0.0 'RS Umum Hermina' 'B' 'Jakarta Timur' '6/9/2017' '5/9/2020'
#   'Tingkat Paripurna']
#  [0.0 1.0 'RS Umum Harapan Bunda' 'B' 'Jakarta Timur' '6/11/2018'
#   '5/11/2021' 'Tingkat Paripurna']
#  [1.0 0.0 'RS Umum Islam Jakarta Utara' 'C' 'Jakarta Utara' '26/04/2017'
#   '25/04/2020' 'Tingkat Paripurna']
#  [0.0 1.0 'RS Khusus Kanker MRCCC Siloam Semang' 'A' 'Jakarta Selatan'
#   '17/09/2018' '16/09/2021' 'Tingkat Paripurna']
#  [0.0 1.0 'RS Umum Daerah Ciracas' 'D' 'Jakarta Timur' '18/02/2019'
#   '17/02/2022' 'Tingkat Utama']
#  [1.0 0.0 'RS Ibu dan Anak Budhi Jaya' 'C' 'Jakarta Selatan' '16/03/2017'
#   '15/03/2020' 'Tingkat Utama']
#  [1.0 0.0 'RS Ibu dan Anak Sammrie Basra' 'B' 'Jakarta Timur'
#   '19/12/2017' '18/12/2020' 'Tingkat Utama']
#  [0.0 1.0 'RS Umum Kramat 128' 'B' 'Jakarta Pusat' '7/5/2019' '6/5/2022'
#   'Tingkat Paripurna']
#  [0.0 1.0 'RS Umum Aulia' 'C' 'Jakarta Selatan' '13/08/2019' '12/8/2022'
#   'Tingkat Utama']
#  [0.0 1.0 'RS Umum Akademik Atma Jaya' 'B' 'Jakarta Utara' '25/02/2019'
#   '24/02/2022' 'Tingkat Paripurna']
#  [1.0 0.0 'RS Umum Pantai Indah Kapuk' 'B' 'Jakarta Utara' '25/07/2017'
#   '24/07/2020' 'Tingkat Utama']
#  [0.0 1.0 'RS Umum Daerah Jati Padang' 'D' 'Jakarta Selatan' '22/04/2019'
#   '21/04/2022' 'Tingkat Paripurna']
#  [0.0 1.0 'RS Umum Pelabuhan Tj. Priok' 'C' 'Jakarta Utara' '18/12/2018'
#   '17/12/2021' 'Tingkat Paripurna']
#  [0.0 1.0 'RS Ketergantungan Obat' 'B' 'Jakarta Timur' '15/10/2019'
#   '14/10/2022' 'Tingkat Utama']
#  [0.0 1.0 'RS Umum Daerah Mampang Prapatan' 'D' 'Jakarta Selatan'
#   '14/05/2019' '13/05/2022' 'Tingkat Utama']
#  [0.0 1.0 'RS Bersalin Kartini' 'C' 'Jakarta Selatan' '19/12/2018'
#   '18/12/2021' 'Lulus Perdana']
#  [0.0 1.0 'RS Kanker Dharmais' 'A' 'Jakarta Barat' '21/05/2018'
#   '20/05/2021' 'Tingkat Paripurna']
#  [0.0 1.0 'RS Umum Siloam TB Simatupang' 'B' 'Jakarta Selatan'
#   '3/12/2018' '2/12/2021' 'Tingkat Paripurna']
#  [1.0 0.0 'RS Umum Husada' 'B' 'Jakarta Pusat' '1/2/2017' '31/01/2020'
#   'Tingkat Paripurna']
#  [0.0 1.0 'RS Umum Pondok Indah' 'B' 'Jakarta Selatan' '10/9/2019'
#   '9/9/2022' 'Tingkat Paripurna']
#  [1.0 0.0 'RS Umum AL Dr Mintoharjo' 'B' 'Jakarta Pusat' '12/12/2017'
#   '11/12/2020' 'Tingkat Paripurna']
#  [1.0 0.0 'RS Umum PAD Gatot Soebroto' 'A' 'Jakarta Pusat' '18/07/2017'
#   '17/07/2020' 'Tingkat Paripurna']
#  [1.0 0.0 'RS Umum Anggrek Mas' 'D' 'Jakarta Barat' '21/12/2017'
#   '20/12/2020' 'Lulus Perdana']
#  [1.0 0.0 'RS Umum Daerah Matraman' 'D' 'Jakarta Timur' '3/10/2017'
#   '2/10/2020' 'Lulus Perdana']
#  [1.0 0.0 'RS Umum Sumber Waras' 'B' 'Jakarta Barat' '11/12/2017'
#   '10/12/2020' 'Tingkat Utama']
#  [0.0 1.0 'RS Umum Menteng Mitra Afia' 'C' 'Jakarta Pusat' '10/6/2019'
#   '9/6/2022' 'Tingkat Madya']
#  [0.0 1.0 'RS Umum Daerah Sawah Besar' 'D' 'Jakarta Pusat' '24/06/2019'
#   '23/06/2022' 'Tingkat Utama']]

# %%
print(y_train)
# Out:
# [35 65 62 48 69 19 37 62 66 14  7  3 83  3 54 23  3 64 65 25 65 61 84 65
#  55 78 32 27 13 77 50 24 82 22  2 63 21 36 67 45 17 20 79 78 69  7 33 15
#  58 31 34  8 68 15 55 72 23 65 51 90 41 78 60  1 78 75 34 86 74 46  8 78
#  10 78 30 55 88 71 81 85 76 11 48 47  3 11  2 82  2 69 60 89 27 12 40 16
#  82 34 73  8 48 73 44 59 28 58  5  0  8 69  8 26 38 27 48  9 18 53 80 48
#  14 89 43 49 19 70 87]

# %%
print(y_test)
# Out:
# [32 61 84 11 66  6 78 33 50 62 73 42 41 66 53  9 76 69 56 53 29 39 69 52
#   8 57 25 42 63  4 48 65]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train[:, 7:] = sc.fit_transform(X_train[:, 7:])
X_test[:, 7:] = sc.transform(X_test[:, 7:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\DWIKIA~1\AppData\Local\Temp/ipykernel_8824/1375767974.py in <module>
#       1 from sklearn.preprocessing import StandardScaler
#       2 sc = StandardScaler()
# ----> 3 X_train[:, 7:] = sc.fit_transform(X_train[:, 7:])
#       4 X_test[:, 7:] = sc.transform(X_test[:, 7:])
#
# NameError: name 'X_train' is not defined
